# %% [markdown]
# ### Viewing Processed Datasets

# %%
import pandas as pd

ff3 = pd.read_parquet("../data/processed/ff3_monthly.parquet")
mom = pd.read_parquet("../data/processed/mom_monthly.parquet")
factors = pd.read_parquet("../data/processed/factors_monthly.parquet")
rets = pd.read_parquet("../data/processed/returns_monthly.parquet")
ports = pd.read_parquet("../data/processed/portfolios_25_5x5_monthly.parquet")

display(ff3.head())
display(factors.describe())
display(rets.tail())
display(mom.head())
display(ports.head())
# Out:
#         date  Mkt-RF   SMB   HML    RF
# 0 1926-07-01    2.89 -2.55 -2.39  0.22
# 1 1926-08-01    2.64 -1.14  3.81  0.25
# 2 1926-09-01    0.38 -1.36  0.05  0.23
# 3 1926-10-01   -3.27 -0.14  0.82  0.32
# 4 1926-11-01    2.54 -0.11 -0.61  0.31
#                                 date       Mkt-RF          SMB          HML  \
# count                           1187  1187.000000  1187.000000  1187.000000
# mean   1976-05-31 20:45:53.833192928     0.006893     0.001708     0.003459
# min              1927-01-01 00:00:00    -0.287400    -0.174100    -0.138300
# 25%              1951-09-16 00:00:00    -0.020050    -0.016300    -0.014400
# 50%              1976-06-01 00:00:00     0.010800     0.000700     0.001400
# 75%              2001-02-15 00:00:00     0.036600     0.017400     0.017600
# max              2025-11-01 00:00:00     0.388100     0.359600     0.355200
# std                              NaN     0.053205     0.031597     0.035623
#
#                 RF          Mom
# ...

# %%
import pandas as pd

ff3 = pd.read_parquet("../data/processed/ff3_monthly.parquet")
mom = pd.read_parquet("../data/processed/mom_monthly.parquet")
factors = pd.read_parquet("../data/processed/factors_monthly.parquet")
rets = pd.read_parquet("../data/processed/returns_monthly.parquet")
ports = pd.read_parquet("../data/processed/portfolios_25_5x5_monthly.parquet")
display(ff3.info())
display(mom.info())
display(factors.info())
display(rets.info())
display(ports.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1193 entries, 0 to 1192
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1193 non-null   datetime64[ns]
#  1   Mkt-RF  1193 non-null   float64
#  2   SMB     1193 non-null   float64
#  3   HML     1193 non-null   float64
#  4   RF      1193 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 46.7 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1187 non-null   datetime64[ns]
#  1   Mom     1187 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 18.7 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
# ...
