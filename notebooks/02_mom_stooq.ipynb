# %%
import pandas as pd

mom = pd.read_parquet("../data/processed/us_momentum_12_1.parquet")
rets = pd.read_parquet("../data/processed/us_monthly_returns.parquet")

display(mom.info())
display(rets.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 0 entries
# Empty DataFrame
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 0 entries
# Empty DataFrame
# None

# %%
raw = pd.read_parquet("../data/raw/us_prices_daily.parquet")
display(raw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 0 entries
# Empty DataFrame
# None

# %%
import sys
sys.path.append("../src")
from cross_sectional_utils import build_deciles

raw = pd.read_parquet("../data/raw/us_prices_daily.parquet")
# print(raw.shape)
rets = pd.read_parquet("../data/processed/us_monthly_returns.parquet")
# display(ret.info())
mom = pd.read_parquet("../data/processed/us_momentum_12_1.parquet")
# display(mom.info())
# ret.describe().T[["count", "mean", "std"]].head()
print(mom.std(axis=1).mean())
print(rets.std(axis=1).mean())
wml = build_deciles(mom, rets)
print(wml.min(), wml.quantile(0.01), wml.median(), wml.quantile(0.99), wml.max())
print("wml mean:", wml.mean())
# Out:
# 0.7575799209235201
# 0.7780554717598138
# -0.39451780712959567 -0.20549464303313295 0.016986699093058208 0.15625439443816727 0.21016690622917636
# wml mean: 0.010778772149812866

# %%
display(wml.info())
display(mom.dropna().head(10))
display(rets.head(10))
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 300 entries, 0 to 299
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 300 non-null    float64
# dtypes: float64(1)
# memory usage: 2.5 KB
# None
# Ticker          RAFE      INSE      VIVS       XVV       DEA      VCEL  \
# Date
# 2022-03-31  0.198737  0.563636 -0.755294  0.193579  0.002424 -0.263049
# 2022-04-30  0.081766  0.551130 -0.630705  0.106467  0.042500 -0.258146
# 2022-05-31  0.064277  0.490909 -0.559719  0.086474  0.036809 -0.387696
# 2022-06-30 -0.032094 -0.189354 -0.694681 -0.022496 -0.046683 -0.495575
# 2022-07-31 -0.009321 -0.137255 -0.743617 -0.048980 -0.019952 -0.482857
# 2022-08-31 -0.099236 -0.257118 -0.769231 -0.148848 -0.117248 -0.524367
# 2022-09-30 -0.065463 -0.187745 -0.616188 -0.098069 -0.013527 -0.399298
# 2022-10-31 -0.063290 -0.105128 -0.652941 -0.093901 -0.083522 -0.488729
# 2022-11-30 -0.193252 -0.357818 -0.669887 -0.233240 -0.208993 -0.495871
# ...

# %%
wml_2000_2009 = wml[:120].mean()
wml_2010_2019 = wml[120:240].mean()
wml_2020 = wml[240:].mean()

print(wml_2000_2009, wml_2010_2019, wml_2020)
# Out:
# -0.008041746935054708 0.013501621264920886 0.026936079279182935
